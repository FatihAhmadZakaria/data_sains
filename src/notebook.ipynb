# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# 1. Load Data
df = pd.read_csv("../data/data.csv", sep=';') # Pastikan separator sesuai, kadang Excel save as CSV pakai koma (,)
df = df.dropna(axis=1, how='all')
df = df.drop(columns=[col for col in df.columns if col.endswith((".3", ".4"))])
df.head()
# Out:
#     tanggal marketplacename        penerima      sku  \
# 0  8/2/2023          Shopee            Dina  AB06680
# 1  8/2/2023          Shopee  Muhammad Soleh  AB05572
# 2  8/2/2023          Tiktok         heriana  AB01073
# 3  8/2/2023          Shopee       Patricia   AB06680
# 4  8/2/2023       Tokopedia       Saddam ()  AB02359
#
#                                 judul  stock tahunterbit  hargabuku  berat  \
# 0             Pengantar Ekonomi Mikro      0   12/8/2021     136000    NaN
# 1  konsep dan aplikasi K3 rumah sakit      0   19/9/2020     143000    0.0
# 2                       Epidemiologi       0    9/2/2015     105000    NaN
# 3             Pengantar Ekonomi Mikro      0   12/8/2021     136000    NaN
# 4                  Domain dan hosting      0   12/5/2017     143000    NaN
#
#    lembartotal  ...  urgent tipetransaksi servicefee  jumlah_order  \
# 0          NaN  ...  Normal     Eksternal          0             3
# 1         79.0  ...  Normal     Eksternal      13507             1
# 2         71.0  ...  Normal     Eksternal          0             1
# 3          NaN  ...  Normal     Eksternal          0             1
# 4        129.0  ...  Normal     Eksternal          0             1
#
#    jumlahcetak  kategoriutama      kategorisekunder       kategoritersier  \
# 0            3        EKONOMI               Ekonomi                   NaN
# 1            1      KESEHATAN       Kedokteran umum  Kesehatan Masyarakat
# 2            1      KESEHATAN  Kesehatan Masyarakat                   NaN
# 3            1        EKONOMI               Ekonomi                   NaN
# 4            1          SAINS  Komputer & Teknologi    Teknik Informatika
#
#                                     kategorigabungan statussku
# 0                               EKONOMI - Ekonomi -      Ganda
# 1  KESEHATAN - Kedokteran umum - Kesehatan Masyar...     Ganda
# 2                KESEHATAN - Kesehatan Masyarakat -      Ganda
# 3                               EKONOMI - Ekonomi -      Ganda
# 4  SAINS - Komputer & Teknologi - Teknik Informatika      Unik
#
# [5 rows x 21 columns]

# %%
print("Ini merupakan dataset yang digunakan")
df.head()
# Out:
# Ini merupakan dataset yang digunakan
#     tanggal marketplacename        penerima      sku  \
# 0  8/2/2023          Shopee            Dina  AB06680
# 1  8/2/2023          Shopee  Muhammad Soleh  AB05572
# 2  8/2/2023          Tiktok         heriana  AB01073
# 3  8/2/2023          Shopee       Patricia   AB06680
# 4  8/2/2023       Tokopedia       Saddam ()  AB02359
#
#                                 judul  stock tahunterbit  hargabuku  berat  \
# 0             Pengantar Ekonomi Mikro      0   12/8/2021     136000    NaN
# 1  konsep dan aplikasi K3 rumah sakit      0   19/9/2020     143000    0.0
# 2                       Epidemiologi       0    9/2/2015     105000    NaN
# 3             Pengantar Ekonomi Mikro      0   12/8/2021     136000    NaN
# 4                  Domain dan hosting      0   12/5/2017     143000    NaN
#
#    lembartotal  ...  urgent tipetransaksi servicefee  jumlah_order  \
# 0          NaN  ...  Normal     Eksternal          0             3
# 1         79.0  ...  Normal     Eksternal      13507             1
# 2         71.0  ...  Normal     Eksternal          0             1
# 3          NaN  ...  Normal     Eksternal          0             1
# 4        129.0  ...  Normal     Eksternal          0             1
#
#    jumlahcetak  kategoriutama      kategorisekunder       kategoritersier  \
# 0            3        EKONOMI               Ekonomi                   NaN
# 1            1      KESEHATAN       Kedokteran umum  Kesehatan Masyarakat
# 2            1      KESEHATAN  Kesehatan Masyarakat                   NaN
# 3            1        EKONOMI               Ekonomi                   NaN
# 4            1          SAINS  Komputer & Teknologi    Teknik Informatika
#
#                                     kategorigabungan statussku
# 0                               EKONOMI - Ekonomi -      Ganda
# 1  KESEHATAN - Kedokteran umum - Kesehatan Masyar...     Ganda
# 2                KESEHATAN - Kesehatan Masyarakat -      Ganda
# 3                               EKONOMI - Ekonomi -      Ganda
# 4  SAINS - Komputer & Teknologi - Teknik Informatika      Unik
#
# [5 rows x 21 columns]
